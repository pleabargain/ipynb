# %% [markdown]
# <a href="https://colab.research.google.com/github/pleabargain/ipynb/blob/master/testing_python_diagrams_library_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Usage
# You'll have to upload your own image, first.
#
# # opinion
# It look promising but I am not quite sure how to make the most of it as yet.
#
# # resources
# https://diagrams.mingrammer.com/docs/nodes/custom
#
#
# Maybe call my images that I create and make a big ass picture book?

# %% [markdown]
# # questions

# %% [markdown]
# # Q: will it support emojis?
# ## A: I don't know yet.
#
# # Q: Can I export the diags as PDFs?
# ## A: yes: (png, jpg, svg, and pdf) are allowed.
# https://diagrams.mingrammer.com/docs/guides/diagram#jupyter-notebooks
#
# # Q: How to change direction of diag?
# ## A: TB for top to bottom LR for left to right
#
# # Q: Can I span multiple pages?
# ## A: Not sure yet.
#
# # Q: can I change the text size under an icon?
# ## A: proably yes, see: https://diagrams.mingrammer.com/docs/guides/diagram

# %%
# !pip install diagrams
# Out:
# ...
#      |████████████████████████████████| 23.2MB 1.5MB/s
# ...
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ...

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom
from urllib.request import urlretrieve

with Diagram("Custom with remote icons", show=False, filename="custom_remote", direction="LR"):

  # download the icon image file
  diagrams_url = "https://github.com/mingrammer/diagrams/raw/master/assets/img/diagrams.png"
  diagrams_icon = "diagrams.png"
  urlretrieve(diagrams_url, diagrams_icon)

  diagrams = Custom("Diagrams", diagrams_icon)

  with Cluster("Some Providers"):

    openstack_url = "https://github.com/mingrammer/diagrams/raw/master/resources/openstack/openstack.png"
    openstack_icon = "openstack.png"
    urlretrieve(openstack_url, openstack_icon)

    openstack = Custom("OpenStack", openstack_icon)

    elastic_url = "https://github.com/mingrammer/diagrams/raw/master/resources/elastic/saas/elastic.png"
    elastic_icon = "elastic.png"
    urlretrieve(elastic_url, elastic_icon)

    elastic = Custom("Elastic", elastic_icon)

  diagrams >> openstack
  diagrams >> elastic
  # diag

# %%
from diagrams import Diagram
from diagrams.aws.compute import EC2

with Diagram("Simple Diagram") as diag:
    EC2("web")
diag

# %% [markdown]
# test use of local images

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom


with Diagram("Here is my custom text!", 
             show=False, 
             filename="change_File_name_here", 
             direction="LR") as diag:
  cc_heart = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
#   cc_attribution = Custom("Credit must be given to the creator", "./my_resources/cc_attribution.png")

#   cc_sa = Custom("Adaptations must be shared\n under the same terms", "./my_resources/cc_sa.png")
#   cc_nd = Custom("No derivatives or adaptations\n of the work are permitted", "./my_resources/cc_nd.png")
#   cc_zero = Custom("Public Domain Dedication", "./my_resources/cc_zero.png")

#   with Cluster("Non Commercial"):
#     non_commercial = [Custom("Y", "./my_resources/cc_nc-jp.png") - Custom("E", "./my_resources/cc_nc-eu.png") - Custom("S", "./my_resources/cc_nc.png")]

  cc_heart
#   cc_heart >> cc_attribution
#   cc_heart >> non_commercial
#   cc_heart >> cc_sa
#   cc_heart >> cc_nd
#   cc_heart >> cc_zero
diag

# %% [markdown]
# # let's pdf output as left to right

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom


with Diagram("Here is my custom text!", 
             show=False, 
             filename="change_File_name_here", 
             direction="LR",
             outformat="pdf") as diag:
  cc_heart = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart1 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart2 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart3 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")

#   cc_attribution = Custom("Credit must be given to the creator", "./my_resources/cc_attribution.png")

#   cc_sa = Custom("Adaptations must be shared\n under the same terms", "./my_resources/cc_sa.png")
#   cc_nd = Custom("No derivatives or adaptations\n of the work are permitted", "./my_resources/cc_nd.png")
#   cc_zero = Custom("Public Domain Dedication", "./my_resources/cc_zero.png")

#   with Cluster("Non Commercial"):
#     non_commercial = [Custom("Y", "./my_resources/cc_nc-jp.png") - Custom("E", "./my_resources/cc_nc-eu.png") - Custom("S", "./my_resources/cc_nc.png")]

  cc_heart >> cc_heart1
  cc_heart1 >> cc_heart2
  cc_heart2 >> cc_heart3
#   cc_heart >> cc_attribution
#   cc_heart >> non_commercial
#   cc_heart >> cc_sa
#   cc_heart >> cc_nd
#   cc_heart >> cc_zero
diag

# %% [markdown]
# # top to bottom

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom


# if you include graph attr don't forget to add it ot the code!
graph_attr = {
    "fontsize": "65",
    "bgcolor": "white"
}

with Diagram("Here is my custom text at 65 font!", 
             show=False, 
             filename="attr", 
             direction="TB",
             graph_attr=graph_attr,
             outformat="png") as diag:
  cc_heart = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart1 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart2 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart3 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart4 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart5 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart6 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")

#   cc_attribution = Custom("Credit must be given to the creator", "./my_resources/cc_attribution.png")

#   cc_sa = Custom("Adaptations must be shared\n under the same terms", "./my_resources/cc_sa.png")
#   cc_nd = Custom("No derivatives or adaptations\n of the work are permitted", "./my_resources/cc_nd.png")
#   cc_zero = Custom("Public Domain Dedication", "./my_resources/cc_zero.png")

#   with Cluster("Non Commercial"):
#     non_commercial = [Custom("Y", "./my_resources/cc_nc-jp.png") - Custom("E", "./my_resources/cc_nc-eu.png") - Custom("S", "./my_resources/cc_nc.png")]

  cc_heart >> cc_heart1
  cc_heart1 >> cc_heart2
  cc_heart2 >> cc_heart3
  cc_heart3 >> cc_heart4
  cc_heart4 >> cc_heart5
  cc_heart5 >> cc_heart6
#   cc_heart >> cc_attribution
#   cc_heart >> non_commercial
#   cc_heart >> cc_sa
#   cc_heart >> cc_nd
#   cc_heart >> cc_zero
diag

# %% [markdown]
# # test adding font control to nodes

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom


# if you include graph attr don't forget to add it ot the code!
graph_attr = {
    "fontsize": "65",
    "bgcolor": "white", # changes color of entire background
}

node_attr ={
    "fontsize": "25",
    "bgcolor": "red",
}

with Diagram("Here is my custom text at 65 font!", 
             show=False, 
             filename="node_attr", 
             direction="TB",
             graph_attr=graph_attr,
             node_attr=node_attr,
             outformat="png") as diag:
  cc_heart = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart1 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart2 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart3 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart4 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart5 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart6 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")

#   cc_attribution = Custom("Credit must be given to the creator", "./my_resources/cc_attribution.png")

#   cc_sa = Custom("Adaptations must be shared\n under the same terms", "./my_resources/cc_sa.png")
#   cc_nd = Custom("No derivatives or adaptations\n of the work are permitted", "./my_resources/cc_nd.png")
#   cc_zero = Custom("Public Domain Dedication", "./my_resources/cc_zero.png")

#   with Cluster("Non Commercial"):
#     non_commercial = [Custom("Y", "./my_resources/cc_nc-jp.png") - Custom("E", "./my_resources/cc_nc-eu.png") - Custom("S", "./my_resources/cc_nc.png")]

  cc_heart >> cc_heart1
  cc_heart1 >> cc_heart2
  cc_heart2 >> cc_heart3
  cc_heart3 >> cc_heart4
  cc_heart4 >> cc_heart5
  cc_heart5 >> cc_heart6
#   cc_heart >> cc_attribution
#   cc_heart >> non_commercial
#   cc_heart >> cc_sa
#   cc_heart >> cc_nd
#   cc_heart >> cc_zero
diag

# %% [markdown]
# # now export as pdf to see how it works with fonts

# %%
from diagrams import Diagram, Cluster
from diagrams.custom import Custom


# if you include graph attr don't forget to add it ot the code!
graph_attr = {
    "fontsize": "65",
    "bgcolor": "white", # changes color of entire background
}

node_attr ={
    "fontsize": "25",
    "bgcolor": "red",
}

with Diagram("Here is my custom text at 65 font!", 
             show=False, 
             filename="testing_pdf_node_attr", 
             direction="TB",
             graph_attr=graph_attr,
             node_attr=node_attr,
             outformat="pdf") as diag:
  cc_heart = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart1 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart2 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart3 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart4 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart5 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")
  cc_heart6 = Custom("You will have to upload\nyour own image!", "/content/cof.png-1.png")

#   cc_attribution = Custom("Credit must be given to the creator", "./my_resources/cc_attribution.png")

#   cc_sa = Custom("Adaptations must be shared\n under the same terms", "./my_resources/cc_sa.png")
#   cc_nd = Custom("No derivatives or adaptations\n of the work are permitted", "./my_resources/cc_nd.png")
#   cc_zero = Custom("Public Domain Dedication", "./my_resources/cc_zero.png")

#   with Cluster("Non Commercial"):
#     non_commercial = [Custom("Y", "./my_resources/cc_nc-jp.png") - Custom("E", "./my_resources/cc_nc-eu.png") - Custom("S", "./my_resources/cc_nc.png")]

  cc_heart >> cc_heart1
  cc_heart1 >> cc_heart2
  cc_heart2 >> cc_heart3
  cc_heart3 >> cc_heart4
  cc_heart4 >> cc_heart5
  cc_heart5 >> cc_heart6
#   cc_heart >> cc_attribution
#   cc_heart >> non_commercial
#   cc_heart >> cc_sa
#   cc_heart >> cc_nd
#   cc_heart >> cc_zero
diag
